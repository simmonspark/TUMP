# %% [markdown]
# # **Real-time object classifier - YOLOv4 / Darknet**

# %% [markdown]
#  1 - Installation/Acquisition of Necessary Files
#
# 2 - Training of the Model
#
# 3 - Validation of the Model

# %% [markdown]
# # **1. Installation**

# %% [markdown]
# Before starting the training of the model, it's necessary to obtain some specific files:
#
# 1. `yolov4.cfg` (a file containing the structure of the neural network and its parameters)
# 2. `obj.names` (a .txt file with the names of the object classes)
# 3. `train & test` (.txt files with the directories of the training and testing images)
# 4. `obj.data` (a .txt file containing the information shown below)
# 5. Pre-trained weights (optional)

# %% [markdown]
# ### 1.1 How to Obtain the yolov4.cfg file

# %%
from google.colab import drive
drive.mount('/content/gdrive')

#Connect COLAB TO GOOGLE DRIVE
#If the Output is "Mounted at ..." then Google Drive is Already Connected

# !git clone https://github.com/AlexeyAB/darknet

#DOWNLOAD FROM DARKNET ALEXEYAB
# Out:
# Mounted at /content/gdrive
# Cloning into 'darknet'...
# remote: Enumerating objects: 15395, done.
# remote: Total 15395 (delta 0), reused 0 (delta 0), pack-reused 15395
# Receiving objects: 100% (15395/15395), 14.02 MiB | 17.72 MiB/s, done.
# Resolving deltas: 100% (10353/10353), done.

# %%
# !cp /content/darknet/cfg/yolov4.cfg /content/gdrive/MyDrive

#COPY YOLOV4.CFG TO GOOGLE DRIVE

# %% [markdown]
# The next step is to edit the 'yolov4.cfg' file using a text editor, modifying the network parameters and changing the name to 'yolov4-custom':
#
#
#
# ![Capturar83.PNG](data:image/png;base64,...)

# %% [markdown]
# ### 1.2 How to obtain the file obj.names

# %% [markdown]
# The obj.names file is a .txt file where each line contains a class of object to be detected, as demonstrated in the image below:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After creating the file, you should copy it to Google Drive.

# %% [markdown]
# ### 1.3 How to obtain train.txt and text.txt

# %% [markdown]
# For this step, a database with images and their respective .txt files containing the coordinates of the targets is required. To obtain a customized database, I would like to refer to the following article:
#
# [Obtain a Customized Database](https://medium.com/analytics-vidhya/image-dataset-labeling-annotation-bec3390eda2d)

# %% [markdown]
# After obtaining the database, you should insert the training images with their corresponding .txt files into a zip file named "obj" and place it on Google Drive;
#
# Also, insert the validation images with their corresponding .txt files into a zip file named "valid" and place it on Google Drive;

# %%
from google.colab import drive
drive.mount('/content/gdrive')

#Connect COLAB to GOOGLE DRIVE
#If the Output is "Mounted at ..." then Google Drive is Already Connected
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-a0b195270f64> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/gdrive')
#       3
#       4 #LIGAR O COLAB AO GOOGLE DRIVE
#       5 #CASO O OUTOUT SEJA "MOUNTED AT ..." O GOOGLE DRIVE JÁ ESTÁ LIGADO
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     113       force_remount=force_remount,
#     114       timeout_ms=timeout_ms,
# --> 115       ephemeral=True)
#     116
#     117
#
# /usr/local/lib/python3.7/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, use_metadata_server, ephemeral)
#     133   if ephemeral:
#     134     _message.blocking_request(
# --> 135         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None)
#     136
# ...

# %%
# !cp /content/gdrive/MyDrive/obj.zip /content/

#Copy train images (ZIP) from GOOGLE DRIVE to COLAB

# %%
# !cp /content/gdrive/MyDrive/valid.zip /content/

#Copy validation images (ZIP) from GOOGLE DRIVE to COLAB

# %%
# !unzip obj.zip -d ./data

#UNPACK folder OBJ to folder DATA

# %%
# !unzip valid.zip -d ./data

#UNPACK folder VALID to folder DATA

# %%
cd /content/

# %%
# !git clone https://github.com/sampaiotorgal/UUV.git

#DOWNLOAD GERAR_TEST.PY and GERAR_TRAIN.PY

# %%
# !cp /content/UUV/gerar_test.py /content/

#Copy GERAR_TEST.PY

# %%
# !cp /content/UUV/gerar_train.py /content/

#COPIAR O FICHEIRO PYTHON GERAR_TRAIN.PY

# %%
# !python /content/gerar_test.py

#EXECUTE GERAR_TEST.PY

# %%
# !python /content/gerar_train.py

#EXECUTE GERAR_TRAIN.PY

# %%
# !cp /content/data/test.txt /content/gdrive/MyDrive/

#COPY TEST.TXT to DRIVE

# %%
# !cp /content/data/train.txt /content/gdrive/MyDrive/

#COPY TRAIN.TXT to DRIVE

# %% [markdown]
# ###1.4 How to obatin obj.data

# %% [markdown]
# The `obj.data` file is a .txt file where you insert the data presented in the image below:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This file can be created manually using Notepad and saved on Google Drive.

# %% [markdown]
# ### 1.5 Como obter os pesos  pré-treinados (Facultativo)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

#Connect COLAB to GOOGLE DRIVE
#If the Output is "Mounted at ..." then Google Drive is Already Connected

# %%
cd /content/gdrive/MyDrive

#OPEN FOLDER MYDRIVE (GOOGLE DRIVE)

# %%
# !wget https://github.com/AlexeyAB/darknet/releases/download/darknet_yolo_v3_optimal/yolov4.conv.137

#DOWNLOAD Pre-trained weights

# %% [markdown]
# # **2.Training**

# %%
from google.colab import drive
drive.mount('/content/gdrive')

#Connect COLAB to GOOGLE DRIVE
#If the Output is "Mounted at ..." then Google Drive is Already Connected
# Out:
# Mounted at /content/gdrive

# %%
cd /content/
# Out:
# /content

# %%
# !git clone https://github.com/AlexeyAB/darknet

#DOWNLOAD DARKNET ALEXEYAB
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15424, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 15424 (delta 0), reused 1 (delta 0), pack-reused 15423
# Receiving objects: 100% (15424/15424), 14.05 MiB | 23.93 MiB/s, done.
# Resolving deltas: 100% (10364/10364), done.

# %%
cd /content/darknet
# Out:
# /content/darknet

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile
# !apt update
# !apt-get install libopencv-dev


#Changes to the Makefile to Enable OpenCV, GPU, and CuDNN
#Install Library
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease [1,581 B]
# Hit:3 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Get:5 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease [21.3 kB]
# Get:7 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:8 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,990 kB]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Ign:11 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# ...

# %%
# !make

#EXECUTE MAKEFILE
# Out:
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:253:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:867:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ...

# %%
# !cp /content/gdrive/MyDrive/obj.zip /content/darknet/data/

#COPY ZIP with TRAIN IMAGES TXT FILES to DATA folder

# %%
cd /content/darknet/data/
# Out:
# /content/darknet/data

# %%
# !unzip obj.zip

#Unpack train images
# Out:
# Archive:  obj.zip
#    creating: obj/
#   inflating: obj/2010_12sep2_ov20_w0n0r0i0_001_png_jpg.rf.ad31a2a02baf42c4072e438170ce3073.jpg
#  extracting: obj/2010_12sep2_ov20_w0n0r0i0_001_png_jpg.rf.ad31a2a02baf42c4072e438170ce3073.txt
#   inflating: obj/2010_12sep2_ov20_w0n0r0i0_001_png_jpg.rf.be80f3e232b1bbd722443b50584d0a82.jpg
#  extracting: obj/2010_12sep2_ov20_w0n0r0i0_001_png_jpg.rf.be80f3e232b1bbd722443b50584d0a82.txt
#   inflating: obj/2010_12sep2_ov20_w0n0r0i0_002_png_jpg.rf.296d5389e11f62b41ce101f724b764b4.jpg
#  extracting: obj/2010_12sep2_ov20_w0n0r0i0_002_png_jpg.rf.296d5389e11f62b41ce101f724b764b4.txt
#   inflating: obj/2010_12sep2_ov20_w0n0r0i0_002_png_jpg.rf.54d1e2678a46e067619bcf31cf5576de.jpg
#  extracting: obj/2010_12sep2_ov20_w0n0r0i0_002_png_jpg.rf.54d1e2678a46e067619bcf31cf5576de.txt
#   inflating: obj/2010_12sep2_ov20_w0n0r0i0_003_png_jpg.rf.0ea490c965ae54e9f433a751176e6902.jpg
# ...

# %%
# !cp /content/gdrive/MyDrive/valid.zip /content/darknet/data

#COPY ZIP with validation images and TXT files to DATA folder

# %%
cd /content/darknet/data/
# Out:
# /content/darknet/data

# %%
# !unzip valid.zip

#unpack valid images
# Out:
# Archive:  valid.zip
#    creating: valid/
#   inflating: valid/2010_12sep2_ov20_w0n0r0i0_007_png_jpg.rf.5d40a92f9e1e82e91f691444429dd41d.jpg
#  extracting: valid/2010_12sep2_ov20_w0n0r0i0_007_png_jpg.rf.5d40a92f9e1e82e91f691444429dd41d.txt
#   inflating: valid/2010_12sep2_ov20_w0n0r0i0_008_png_jpg.rf.a35edc00b1356ae0db902def0914db67.jpg
#  extracting: valid/2010_12sep2_ov20_w0n0r0i0_008_png_jpg.rf.a35edc00b1356ae0db902def0914db67.txt
#   inflating: valid/2010_12sep2_ov20_w0n0r0i0_010_png_jpg.rf.4269a028c0f7656fdf2c59cd81a1f8e9.jpg
#  extracting: valid/2010_12sep2_ov20_w0n0r0i0_010_png_jpg.rf.4269a028c0f7656fdf2c59cd81a1f8e9.txt
#   inflating: valid/2010_12sep2_ov20_w0n0r0i0_012_png_jpg.rf.a44f4f98526c0c0aeb06d3c066c3d302.jpg
#  extracting: valid/2010_12sep2_ov20_w0n0r0i0_012_png_jpg.rf.a44f4f98526c0c0aeb06d3c066c3d302.txt
#   inflating: valid/2010_12sep2_ov20_w0n0r0i0_013_png_jpg.rf.1336f255d580cea6998c0c0a70384291.jpg
# ...

# %%
# !cp /content/gdrive/MyDrive/yolov4-custom.cfg /content/darknet/cfg

#COPY YOLOV4-CUSTOM to CFG folder

# %%
# !cp /content/gdrive/MyDrive/obj.names /content/darknet/data

#COPY OBJ.NAMES to DATA folder

# %%
# !cp /content/gdrive/MyDrive/obj.data /content/darknet/data

#COPY OBJ.DATA to DATA folder

# %%
# !cp /content/gdrive/MyDrive/train.txt /content/darknet/data

#COPY TRAIN.TXT to DATA folder

# %%
# !cp /content/gdrive/MyDrive/test.txt /content/darknet/data

#COPY TEST.TXT to DATA folder

# %%
# !cp /content/gdrive/MyDrive/yolov4.conv.137 /content/darknet/data

#COPY pre-trained weights to DATA folder
# Out:
# cp: cannot stat '/content/gdrive/MyDrive/yolov4.conv.137': No such file or directory

# %%
cd /content/darknet
# Out:
# /content/darknet

# %% [markdown]
# If You Intend to Start Training with Pre-trained Weights:

# %%
# !./darknet detector train /content/darknet/data/obj.data /content/gdrive/MyDrive/yolov4-custom.cfg /content/darknet/data/yolov4.conv.137 -dont_show -map

#Start of Training with Pre-trained Weights

# %% [markdown]
# If You Intend to Start Training **without** Pre-trained Weights:

# %%
# !./darknet detector train /content/darknet/data/obj.data /content/darknet/cfg/yolov4-custom.cfg  -dont_show -map

#Start of Training without Pre-trained Weights

# %% [markdown]
# To Continue with the Already Initiated Training:

# %%
# !./darknet detector train /content/darknet/data/obj.data /content/gdrive/MyDrive/yolov4-custom.cfg /content/gdrive/MyDrive/yolov4-custom_last.weights -dont_show -map

# %% [markdown]
# # **3. Validation**

# %%
cd /content/darknet
# Out:
# /content/darknet

# %%
#!./darknet detector map /content/gdrive/MyDrive/obj.data /content/gdrive/MyDrive/yolov4-custom.cfg /content/gdrive/MyDrive/yolov4-custom_last.weights
#!./darknet detector map /content/gdrive/MyDrive/obj.data /content/gdrive/MyDrive/yolov4-custom.cfg /content/gdrive/MyDrive/yolov4-custom_1000.weights
#!./darknet detector map /content/gdrive/MyDrive/obj.data /content/gdrive/MyDrive/yolov4-custom.cfg /content/gdrive/MyDrive/yolov4-custom_2000.weights
#!./darknet detector map /content/gdrive/MyDrive/obj.data /content/gdrive/MyDrive/yolov4-custom.cfg /content/gdrive/MyDrive/yolov4-custom_3000.weights
#!./darknet detector map /content/gdrive/MyDrive/obj.data /content/gdrive/MyDrive/yolov4-custom.cfg /content/gdrive/MyDrive/yolov4-custom_4000.weights
# !./darknet detector map /content/gdrive/MyDrive/obj.data /content/gdrive/MyDrive/yolov4-custom.cfg /content/gdrive/MyDrive/yolov4-custom_5000.weights -thresh 0.01
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 0, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    512 x 512 x   3 ->  512 x 512 x  32 0.453 BF
#    1 conv     64       3 x 3/ 2    512 x 512 x  32 ->  256 x 256 x  64 2.416 BF
#    2 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    3 route  1 		                           ->  256 x 256 x  64
#    4 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    5 conv     32       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  32 0.268 BF
#    6 conv     64       3 x 3/ 1    256 x 256 x  32 ->  256 x 256 x  64 2.416 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 256 x 256 x  64 0.004 BF
# ...

# %%
def imShow(path):
  import cv2
  import matplotlib.pyplot as plt
  # %matplotlib inline

  image = cv2.imread(path)
  height, width = image.shape[:2]
  resized_image = cv2.resize(image,(3*width, 3*height), interpolation = cv2.INTER_CUBIC)

  fig = plt.gcf()
  fig.set_size_inches(18, 10)
  plt.axis("off")
  plt.imshow(cv2.cvtColor(resized_image, cv2.COLOR_BGR2RGB))



#Define IMSHOW function

# %%
# !./darknet detector test /content/gdrive/MyDrive/obj.data /content/gdrive/MyDrive/yolov4-custom.cfg /content/gdrive/MyDrive/yolov4-custom_5000.weights /content/gdrive/MyDrive/Imagem01.png -thresh 0.5

imShow('predictions.jpg')

#Test the Model with an Image Named "Imagem01.png" Placed on Google Drive:
# Out:
#  GPU isn't used
#  OpenCV isn't used - data augmentation will be slow
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 conv     32       3 x 3/ 1    512 x 512 x   3 ->  512 x 512 x  32 0.453 BF
#    1 conv     64       3 x 3/ 2    512 x 512 x  32 ->  256 x 256 x  64 2.416 BF
#    2 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    3 route  1 		                           ->  256 x 256 x  64
#    4 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    5 conv     32       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  32 0.268 BF
#    6 conv     64       3 x 3/ 1    256 x 256 x  32 ->  256 x 256 x  64 2.416 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 256 x 256 x  64 0.004 BF
#    8 conv     64       1 x 1/ 1    256 x 256 x  64 ->  256 x 256 x  64 0.537 BF
#    9 route  8 2 	                           ->  256 x 256 x 128
# ...
